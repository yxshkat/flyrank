# %% [markdown]
# <a href="https://colab.research.google.com/github/yxshkat/flyrank/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# !git clone https://github.com/yxshkat/flyrank.git
# %cd flyrank
# Out:
# Cloning into 'flyrank'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 98 (delta 20), reused 79 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 1.84 MiB | 12.53 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/flyrank/flyrank/flyrank/flyrank

# %%
# !pwd
# !ls
# !ls data
# !ls data/raw
# Out:
# /content/flyrank/flyrank/flyrank/flyrank
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission
# raw
# content_refresh_anonymized.csv

# %%
print("""
Lane: Content Refresh / Declining Pages

I chose the Content Refresh lane because the goal is to identify pages that are likely declining and should be reviewed or updated. This problem is practical since websites often contain many pages, making it difficult to decide which ones deserve attention first. A machine learning model can help prioritize these pages using measurable signals such as impressions, CTR, page age, and search position.
""")
# Out:
# Lane: Content Refresh / Declining Pages
#
# I chose the Content Refresh lane because the goal is to identify pages that are likely declining and should be reviewed or updated. This problem is practical since websites often contain many pages, making it difficult to decide which ones deserve attention first. A machine learning model can help prioritize these pages using measurable signals such as impressions, CTR, page age, and search position.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("""
Decision:
Which pages should be prioritized for content updates?

Action:
A content or SEO team reviews and refreshes the pages predicted to be declining.

Cost of a wrong recommendation:
If the model misses a declining page, valuable traffic may continue to fall. If it incorrectly recommends a healthy page, time and effort may be wasted updating content that does not need attention.
""")
# Out:
# Decision:
# Which pages should be prioritized for content updates?
#
# Action:
# A content or SEO team reviews and refreshes the pages predicted to be declining.
#
# Cost of a wrong recommendation:
# If the model misses a declining page, valuable traffic may continue to fall. If it incorrectly recommends a healthy page, time and effort may be wasted updating content that does not need attention.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Pages with declining trend:",
      (df["trend_direction"].str.lower() == "down").sum())
# Out:
# Total pages: 30000
# Average CTR: 0.511
# Pages with declining trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""
This project can identify patterns that are associated with declining pages and provide decision support for content prioritization.

It cannot prove that these features cause rankings to change, predict Google's algorithm, or guarantee that updating a page will improve its performance.
""")
# Out:
# This project can identify patterns that are associated with declining pages and provide decision support for content prioritization.
#
# It cannot prove that these features cause rankings to change, predict Google's algorithm, or guarantee that updating a page will improve its performance.

# %%
import os

print("Current directory:")
print(os.getcwd())
# Out:
# Current directory:
# /content/flyrank/flyrank/flyrank/flyrank

# %%
# !find . -name "content_refresh_anonymized.csv"
# Out:
# ./data/raw/content_refresh_anonymized.csv

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
